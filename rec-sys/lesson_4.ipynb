# %% [markdown]
# # ДЗ 4. Рекомендательные системы на основе контента

# %% [markdown]
# ### Задание 1.
# Ответьте на вопросы:
# a. В чем принципиальное отличие гибридных рекомендательных систем от коллаборативной фильтрации?
# b. Приведите 2-3 примера задач, в которых необходимо использовать гибридные системы?
#
# a. Принципиальное отличие данных систем в том, что в гибридных рекомендательных системах помимо факта взаимодействия используются различные внешние признаки (фичи), как пользователей, так и товаров, а вот в коллаборативной фильтрации учитываются только взаимодействия пользователей с товарами.
#
# b. В первую очередь это задачи:
# - с холодным стартом, т.е. без истории действий пользователя
# - когда мы имеем сильно разреженную user_item матрицу

# %% [markdown]
# ### Задание 2.
# Прочитайте статью про поиск на hh.ru https://habr.com/ru/company/hh/blog/347276/
# Нам интересна именно рекомендательная система, раздел "Производительность системы" можно пропустить.
# a. Какие основные отличия предложенной системы от тех подходов, которые мы разбирали на семинарах?
# b. Какие проблемы могут возникнуть при выводе такой модели в продакшен?
#
# a. Основное отличе в том, что используется воронка фильтров, чтобы отсечь все лишнее, а затем индекс, простое ранжирование и XGBoost для сложного ранжирования. То есть мы имеем нетиповую структуту рекомендательной системы.
#
# b. Основная проблема с которой столкнулись разработчики, это значительное увелечение ресурсов и дополнительное время на обработку запросов, что потребовало пересмотр всей архитектуры проекта. Помимо этого существует и другая проблема - предпочтения пользователей все время меняются, что требует постоянных улучшений алгоримта поиска, а это в свою очередь тянет за собою необходимость изменения структуры проекта. Другими словами, такая система не очень приспособлена для быстрых изменений.

# %% [markdown]
# ### Задание 3.
# На вебинаре мы рассматривали модель LightFM (https://making.lyst.com/lightfm/docs/lightfm.html). В работе Data Scientist'а важную часть занимает research - исследование существующих архитектур и разбор научных статей, в которых они описываются. Вам предлагается изчуть оригинальную статью про LightFM https://arxiv.org/pdf/1507.08439.pdf и ответить на следующие вопросы:
# a. Какой датасет используют авторы?
# b. Что используют в качестве признаков?
# c. С какими моделями сравнивают LightFM? Опишите их основные идеи кратко.
#
# a. Используется 2 датасета:
# - MovieLens - большой датасет состоит примерно из 10 миллионов рейтингов фильмов с данными об истории взаимодействий пользователей с этими фильмами
# - CrossValidated - датасет с данными о пользовательских вопросах и ответах на них
#
# b. В качестве признаков используется:
# - Для MovieLens - жанры, тэги, рейтинг тега, оценки пользователей
# - Для CrossValidated - вопросы пользователей и ответы на них
#
# c. LightFM сравнивают с:
# - MF: модель колаборативной фильтрации (матричная модель user - item с функцией сигмойды)
# - LSI-LR: модель логистической регрессии (основывается на факторизации матрицы контента)
# - LSI-UP: гибридная модель (представляющая профили пользователей (UP) в виде линейных комбинаций векторов содержимого элементов)
