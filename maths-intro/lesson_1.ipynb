# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import random

# %%
k = 1
s = random.randint(k+1, k+5)
x = np.linspace(0, 10, 130)
plt.plot(x, np.cos(k*x), marker='o')
plt.plot(x, np.cos((k+s)*x), marker='o')
